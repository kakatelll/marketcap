# %%
import pandas as pd
import numpy as np

xls = pd.ExcelFile("hk_603ipo_mrk_value.xlsm")
df = pd.read_excel(xls, 'Sheet1')
df['Name']=df['Name'].str.strip("<>")
df.columns = df.columns.astype(str)
df.columns = df.columns.str.replace("00:00:00","")
df.columns = df.columns.str.strip(" ")
df
# Out:
#         Name 1988-12-30  1989-01-02  1989-01-03  1989-01-04  1989-01-05  \
# 0    1353.HK        NaN         NaN         NaN         NaN         NaN
# 1    1439.HK        NaN         NaN         NaN         NaN         NaN
# 2    1247.HK        NaN         NaN         NaN         NaN         NaN
# 3    3332.HK        NaN         NaN         NaN         NaN         NaN
# 4    2080.HK        NaN         NaN         NaN         NaN         NaN
# ..       ...        ...         ...         ...         ...         ...
# 598  6049.HK        NaN         NaN         NaN         NaN         NaN
# 599  9928.HK        NaN         NaN         NaN         NaN         NaN
# 600  9909.HK        NaN         NaN         NaN         NaN         NaN
# 601  9911.HK        NaN         NaN         NaN         NaN         NaN
# 602  1542.HK        NaN         NaN         NaN         NaN         NaN
#
#      1989-01-06  1989-01-09  1989-01-10  1989-01-11  ...  2020-06-18  \
# ...

# %%
a = pd.read_csv('data_TR.csv',usecols=['Instrument','IPO Date','TRBC Economic Sector Name'])
# change date format
a["IPO Date"] = pd.to_datetime(a["IPO Date"]).dt.strftime('%Y-%m-%d')
a
# Out:
#     Instrument    IPO Date TRBC Economic Sector Name
# 0      1353.HK  2014-09-01        Consumer Cyclicals
# 1      1439.HK  2014-01-13           Basic Materials
# 2      1247.HK  2014-01-15        Consumer Cyclicals
# 3      3332.HK  2014-01-15        Consumer Cyclicals
# 4      2080.HK  2014-01-23               Real Estate
# ..         ...         ...                       ...
# 600    9928.HK  2019-12-19               Real Estate
# 601    6199.HK  2019-12-30                Financials
# 602    9909.HK  2019-12-30        Consumer Cyclicals
# 603    9911.HK  2019-12-31        Consumer Cyclicals
# 604    1542.HK  2019-12-31                 Utilities
#
# [605 rows x 3 columns]

# %%
ipodate=a.loc[a["Instrument"] == "1353.HK", "IPO Date"].values[0]
ipodate
# Out:
# '2014-09-01'

# %%
df.loc[df['Name']=="1353.HK",ipodate].values[0]
# Out:
# 160.79

# %%
stockname=a['Instrument'].values
#stockname
#ipodates=a['IPO Date'].values

for stock in stockname:
    ipodate=a.loc[a["Instrument"] == stock,"IPO Date"].values[0]
ipodate
   #marketcap=df.loc[df["Name"]== stock,ipodate].values[0]
# Out:
# '2019-12-31'
